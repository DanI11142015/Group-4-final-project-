# %%
# Dependencies and Setup
import pandas as pd

# %%
# Read and store content
# of an excel file 
read_file = pd.read_excel ("resources/hospital.xls")
  
# Write the dataframe object
# into csv file
read_file.to_csv ("resources/hospitals.csv", 
                  index = None,
                  header=True)
    
# read csv file and convert 
# into a dataframe object
hospitals_df = pd.DataFrame(pd.read_csv("resources/hospitals.csv"))
  
# show the dataframe
hospitals_df
# Out:
#                                          Facility Name  \
# 0    Adventist Bolingbrook Hospital - DBA AdventHea...
# 1    Adventist GlenOaks Hospital - DBA AdventHealth...
# 2    Adventist Midwest Health - DBA AdventHealth Hi...
# 3    Adventist Midwest Health - DBA AdventHealth La...
# 4            Advocate Christ Hospital & Medical Center
# ..                                                 ...
# 206  Van Matre Encompass Health Rehabilitation Hosp...
# 207                   Wabash General Hospital District
# 208                Warner Hospital and Health Services
# 209                         Washington County Hospital
# 210  Waukegan Illinois Hospital Company, LLC - DBA ...
#
#                             Address              City      County    Zip  \
# 0                500 Remington Blvd       Bolingbrook        Will  60440
# 1                  701 Winthrop Ave  Glendale Heights     Du Page  60139
# 2              120 North Oak Street          Hinsdale     Du Page  60521
# ...

# %%
# File to Load
dx_data = pd.read_csv("resources/symptoms_and_dx.csv")
dx_data
# Out:
#      105                    Panic disorder  \
# 0    106                  Vocal cord polyp
# 1    107                   Turner syndrome
# 2    108                    Cryptorchidism
# 3    109  Poisoning due to ethylene glycol
# 4    110                Atrophic vaginitis
# ..   ...                               ...
# 790  602                    Kaposi sarcoma
# 791  603                 Spondylolisthesis
# 792  604               Pseudotumor cerebri
# 793  605       Conjunctivitis due to virus
# 794  606            Open wound of the nose
#
#                [{"symptoms":"Anxiety and nervousness"}  {"symptoms":"88"}  \
# 0                         [{"symptoms":"Hoarse voice"}  {"symptoms":"91"}
# 1                           [{"symptoms":"Groin mass"}  {"symptoms":"27"}
# 2    [{"symptoms":"Symptoms of the scrotum and test...  {"symptoms":"50"}
# 3                      [{"symptoms":"Abusing alcohol"}  {"symptoms":"78"}
# ...

# %%
dx_data.columns
# Out:
# Index(['105', 'Panic disorder', '[{"symptoms":"Anxiety and nervousness"}',
#        '{"symptoms":"88"}', '{"symptoms":"Depression"}', '{"symptoms":"55"}',
#        '{"symptoms":"Shortness of breath"}', '{"symptoms":"40"}',
#        '{"symptoms":"Depressive or psychotic symptoms"}', '{"symptoms":"33"}',
#        ...
#        'Unnamed: 100', 'Unnamed: 101', 'Unnamed: 102', 'Unnamed: 103',
#        'Unnamed: 104', 'Unnamed: 105', 'Unnamed: 106', 'Unnamed: 107',
#        'Unnamed: 108', 'Unnamed: 109'],
#       dtype='object', length=110)

# %%
dx_data1= dx_data[['105', 'Panic disorder', '[{"symptoms":"Anxiety and nervousness"}',
       '{"symptoms":"88"}', '{"symptoms":"Depression"}', '{"symptoms":"55"}',
       '{"symptoms":"Shortness of breath"}', '{"symptoms":"40"}',
       '{"symptoms":"Depressive or psychotic symptoms"}', '{"symptoms":"33"}']]

dx_data1
# Out:
#      105                    Panic disorder  \
# 0    106                  Vocal cord polyp
# 1    107                   Turner syndrome
# 2    108                    Cryptorchidism
# 3    109  Poisoning due to ethylene glycol
# 4    110                Atrophic vaginitis
# ..   ...                               ...
# 790  602                    Kaposi sarcoma
# 791  603                 Spondylolisthesis
# 792  604               Pseudotumor cerebri
# 793  605       Conjunctivitis due to virus
# 794  606            Open wound of the nose
#
#                [{"symptoms":"Anxiety and nervousness"}  {"symptoms":"88"}  \
# 0                         [{"symptoms":"Hoarse voice"}  {"symptoms":"91"}
# 1                           [{"symptoms":"Groin mass"}  {"symptoms":"27"}
# 2    [{"symptoms":"Symptoms of the scrotum and test...  {"symptoms":"50"}
# 3                      [{"symptoms":"Abusing alcohol"}  {"symptoms":"78"}
# ...

# %%
merged_data = pd.merge(dx_data1, hospitals, how="outer", left_on="Panic disorder", right_on="Topic"])
merged_data
# Out:
#   File "C:\Users\degin\AppData\Local\Temp\ipykernel_15212\1655973741.py", line 1
#     merged_data = pd.merge(dx_data1, hospitals, how="outer", left_on="Panic disorder", right_on="Topic"])
#                                                                                                        ^
# SyntaxError: invalid syntax
